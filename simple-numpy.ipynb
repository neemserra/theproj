# %%
print 'hello, world'
# Out:
# hello, world

# %%
import randomx = []for i in range(100):    x.append(random.randint(0, 1000))    y = []for num in x:    num2 = num + random.randint(0, 500) - 250    y.append(num2)

# %%
plot(x,y, '.')

# %%
from numpy import polyfitpolyfit?

# %%
fit_params = polyfit(x, y, 1)

# %%
fit_line = polyval(fit_params, x)

# %%
plot(x, y, 'b.')plot(x, fit_line, 'r-')

# %%
avgs = []for i in range(1000):    x = []    for i in range(200):        x.append(random.randint(1, 1000))    avgs.append(sum(x) / float(len(x)))

# %%
hist(avgs, bins=100)
# Out:
# (array([ 2,  0,  0,  0,  0,  0,  2,  0,  0,  0,  0,  2,  1,  2,  3,  1,  0,        3,  4,  5,  3,  3,  5,  1,  9,  3,  6,  7,  9, 10,  8,  8, 10, 11,       18, 16, 16, 19, 20, 17, 23, 23, 19, 19, 19, 22, 18, 19, 27, 29, 22,       32, 20, 17, 15, 17, 25, 27, 25, 27, 27, 23, 23, 11, 25, 16, 17, 15,       13, 19, 11, 11,  8, 11, 10,  7, 10, 15,  8,  6,  4,  5,  4,  5,  0,        2,  6,  5,  0,  3,  1,  0,  3,  1,  1,  1,  0,  1,  2,  1]), array([ 436.08  ,  437.2993,  438.5186,  439.7379,  440.9572,  442.1765,        443.3958,  444.6151,  445.8344,  447.0537,  448.273 ,  449.4923,        450.7116,  451.9309,  453.1502,  454.3695,  455.5888,  456.8081,        458.0274,  459.2467,  460.466 ,  461.6853,  462.9046,  464.1239,        465.3432,  466.5625,  467.7818,  469.0011,  470.2204,  471.4397,        472.659 ,  473.8783,  475.0976,  476.3169,  477.5362,  478.7555,        479.9748,  481.1941,  482.4134,  483.6327,  484.852 ,  486.0713,        487.2906,  488.5099,  489.7292,  490.9485,  49
# ...

# %%
a
